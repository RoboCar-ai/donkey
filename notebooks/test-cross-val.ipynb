# %%
from keras.models import Model, load_model
from donkeycar.parts.keras import KerasAppInceptionV3Loc1024
import matplotlib.pyplot as plt
# %matplotlib inline

model = KerasAppInceptionV3Loc1024()
model.load_weights('../d2/models/KerasAppInceptionV3Loc1024-cross-val-fold-0.h5')

# %%
img = plt.imread('../d2/data/default_track_sim/center_lane/999_cam-image_array_.jpg')
plt.imshow(img)

# %%
model.run(img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-157866f10f19> in <module>
# ----> 1 model.run(img)
#
# ~/donkey/donkeycar/parts/keras.py in run(self, img_arr)
#     333         outputs = self.model.predict(img_arr[None, ...])
#     334         return outputs
# --> 335
#     336
#     337 class KerasIMU(KerasPilot):
#
# IndexError: invalid index to scalar variable.
